# %%
print('This is a code cell')
# Out:
# This is a code cell

# %%
print('Run cell with shift-enter')
# Out:
# Run cell with shift-enter

# %% [markdown]
# This is a markdown cell (regular code, not text)

# %% [markdown]
# ### Let's make this a header

# %%
1 + 2
# Out:
# 3
